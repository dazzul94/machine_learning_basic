# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.18.2-cp37-cp37m-win_amd64.whl (12.8 MB)
# Installing collected packages: numpyNote: you may need to restart the kernel to use updated packages.
# Successfully installed numpy-1.18.2

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.2.1-cp37-cp37m-win_amd64.whl (9.2 MB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.1.0-cp37-none-win_amd64.whl (57 kB)
# Requirement already satisfied: numpy>=1.11 in c:\users\dazzul\anaconda3\envs\pyml\lib\site-packages (from matplotlib) (1.18.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\dazzul\anaconda3\envs\pyml\lib\site-packages (from matplotlib) (2.8.1)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: setuptools in c:\users\dazzul\anaconda3\envs\pyml\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (46.0.0.post20200309)
# Requirement already satisfied: six in c:\users\dazzul\anaconda3\envs\pyml\lib\site-packages (from cycler>=0.10->matplotlib) (1.14.0)
# Installing collected packages: kiwisolver, cycler, pyparsing, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 matplotlib-3.2.1 pyparsing-2.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline # notebook을 실행한 브라우저에서 바로 그림을 볼 수 있게 해주는 것 입니다.

# data 작성
np.random.seed(1) # random number
x = np.arange(10)
y = np.random.rand(10)

# 그래프 표시
plt.plot(x, y) # 꺾은선 그래프를 
plt.show() # 그래프 그리기
