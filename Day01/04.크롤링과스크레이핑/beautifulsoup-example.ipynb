# %%
#------------------------------------------------
# BeautifulSoup example 
#------------------------------------------------
 
 # package import
from bs4 import BeautifulSoup
import os
os.getcwd()
# 1) html 파일 열기
with open("./example.html") as fp:
  soup = BeautifulSoup(fp, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Page title</title>
# </head>
# <body>
# <div>
# <p>a</p>
# <p>b</p>
# <p>c</p>
# </div>
# <div class="ex_class">
# <p>d</p>
# <p>e</p>
# <p>f</p>
# </div>
# <div id="ex_id">
# <p>g</p>
# <p>h</p>
# <p>i</p>
# </div>
# <h1>This is a heading</h1>
# <p>This is a paragraph.</p>
# <p>This is another paragraph.</p>
# </body>
# </html>

# %%
# 2) urllib를 통해서 웹에 있는 소스 가져오기
import urllib.request
import urllib.parse

# web_url에 원하는 웹의 URL을 넣어주시면 됩니다.
os.getcwd()
# web_url = "./example.html"
web_url = "https://news.v.daum.net/v/20200321131028118"
with urllib.request.urlopen(web_url) as response:
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')    
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="always" name="referrer"/>
# <title>당 간판이 어째.. 국민 마음과 비례 않는 비례대표 | Daum 뉴스</title>
# <link href="//m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <style>
# @charset "utf-8";@font-face{font-family:'Nanum Myeongjo';font-style:normal;font-weight:400;src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot);src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot?#iefix) format('embedded-opentype'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff2) format('woff2'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff) format('woff'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.ttf) format('truetype')}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,textarea,button{margin:0;padding:0}fieldset,img{border:0 none}dl,ul,ol,menu,li{list-style:none}blockquote,q{quotes:none}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none}input,select,textarea,button{vertical-align:middle}input::-ms-clear{display:none}button{border:0 none;background-color:transparent;cursor:pointer}button::-moz-focus-inner{padding:0;border:0}body{min-width:980px;background:#fff}body,th,td,input,select,textarea,button{font-size:14px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,'Malgun Gothic','맑은 고딕',dotum,'돋움',sans-serif;color:#333;letter-spacing:-0.05em}a{color:#333;text-decoration:none}a:active,a:hover{text-decoration:underline}a:hover{color:#1e88e5}a:active{background-color:transparent}address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}.os_mac strong{font-weight:normal;font-family:AppleSDGothicNeo-Regular,sans-serif}html{overflow-y:scroll}#kakaoIndex{overflow:hidden;position:absolute;left:-9999px;width:0;height:1px;margin:0;padding:0}.ir_pm{display:block;overflow:hidden;font-size:0;line-height:0;text-indent:-9999px}.ir_wa{display:block;overflow:hidden;position:relative;z-index:-1;width:100%;height:100%}.screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}.show{display:block}.hide{display:none}.txt_newsview{display:block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/txt_newsview_190618.png) 0 0 no-repeat;text-indent:-9999px;background-size:140px 750px}.ico_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview_190327.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:350px 350px}.ico_newsview2{background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview2_180510.png) 0 0 no-repeat;background-size:50px 440px}.num_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/num_newsview.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:18px 600px}.link_cont,.link_thumb,.tit_g,.tit_thumb,.desc_thumb,.info_thumb{display:block}.link_thumb{position:relative}.link_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:''}.link_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;transition:background .2s,opacity .2s;content:''}.link_thumb:hover:after{background:#508dee;opacity:.45}.link_cont .wrap_thumb{display:block;position:relative}.link_cont .wrap_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:''}.link_cont .wrap_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;transition:background .2s,opacity .2s;content:''}.link_cont:hover .wrap_thumb:after{background:#508dee;opacity:.45}.cont_thumb{overflow:hidden}.inner_cont{display:table;width:100%;height:100%;table-layout:fixed}.inner_cont2{display:table-cell;vertical-align:middle}.thumb_g{vertical-align:top}.emph_g,.emph_g .link_txt{color:#396dbb}.emph_g2,.emph_g2 .link_txt{ ...
#
# .hcg_media_pc_cSub .btn_summary:focus{outline:none}
# .hcg_media_pc_kakaoHead .header_fixed .bar_progress{transition:width .4s ease-out;transform:rotateZ(0deg)}.hcg_media_pc_kakaoHead #kakaoGnb .inner_gnb{transform:rotateZ(0deg)}.hcg_media_pc_kakaoHead .news_type4 #mAside{position:relative;top:0}.hcg_media_pc_kakaoHead .news_type4 #mAside #floatingAside{transform:rotateZ(0deg)}.hcg_media_pc_kakaoHead .news_type4 #mAside .fixed{position:fixed;z-index:100}.hcg_media_pc_kakaoHead .news_type4 #mAside .fixed_bottom{position:relative !important;left:0 !important}.hcg_media_pc_kakaoHead .btn_empathy #empathy_pc .inner_empathy .btn_empathy{width:121px}.hcg_media_pc_kakaoHead .btn_empathy #empathy_pc .inner_empathy .img_empathy{background:none}.hcg_media_pc_kakaoHead .relate_series{display:none}.hcg_media_pc_kakaoHead .relate_series .link_prev img{margin-right:8px}.hcg_media_pc_kakaoHead .relate_series .link_next img{margin-left:8px}.hcg_media_pc_kakaoHead .chooad{margin-bottom:40px}.hcg_media_pc_kakaoHead .layer_summary .desc_summary .add_bottom{display:block;margin-bottom:20px}.hcg_media_pc_kakaoHead .gnb_comm .bar_gnb{display:inherit}.hcg_media_pc_kakaoHead .bar_gnb .inner_bar{width:0;transition:width .2s ease-in-out}.hcg_media_pc_kakaoHead #kakaoGnb .gnb_comm li:hover>a .bar_gnb .inner_bar{width:100%}
# .hcg_media_pc_mArticle .tit_subtxt1{margin:29px 15px;font-weight:normal;font-size:1.35em;line-height:1.36}.hcg_media_pc_mArticle .tit_subtxt1:first-child{margin-top:0}.hcg_media_pc_mArticle .tit_subtxt2{margin:31px 15px 10px;font-size:1.18em;line-height:1.36}.hcg_media_pc_mArticle .tit_subtxt2:first-child{margin-top:0}.hcg_media_pc_mArticle .quote_frm{overflow:hidden;position:relative;margin-bottom:30px;padding:25px 14px 0;font-weight:normal;font-size:1.24em;line-height:1.49;font-family:NanumMyeongjo,나눔명조,serif;text-align:center}.hcg_media_pc_mArticle .quote_frm:before{display:block;position:absolute;top:0;left:50%;width:15px;height:14px;margin-left:-7px;background:url(//m1.daumcdn.net/img-media/storyfunding/m320/img_quote.png) no-repeat;content:''}.hcg_media_pc_mArticle .talkquote_frm{overflow:hidden;position:relative;margin:29px 15px;padding-left:15px;line-height:1.6}.hcg_media_pc_mArticle .talkquote_frm:before{display:block;position:absolute;top:2px;left:0;width:2px;height:100%;background-color:#222;content:''}.hcg_media_pc_mArticle .talkquote_frm:after{display:block;position:absolute;bottom:0;left:0;width:2px;height:5px;background-color:#fff;content:''}.hcg_media_pc_mArticle .talkquote_frm .info_source{display:block;font-size:.76em;line-height:1.8;color:#808080}.hcg_media_pc_mArticle .talkquote_frm:first-child{margin-top:0}.hcg_media_pc_mArticle .talkquote_frm+.talkquote_frm{margin-top:31px}.hcg_media_pc_mArticle .talkquote_frm+div{margin-top:31px}.hcg_media_pc_mArticle [class*="tit_subtxt"]+.talkquote_frm{margin-top:10px}.hcg_media_pc_mArticle .figure_frm{display:block;margin:32px auto 30px auto;padding:0 15px;clear:left}.hcg_media_pc_mArticle .figure_frm .box_figure{display:block;padding:0 15px}.hcg_media_pc_mArticle .figure_frm .link_figure{display:block;position:relative}.hcg_media_pc_mArticle .slide_fig .link_figure:after{border:1px solid #000;opacity:.05;-ms-filter:"progid:DXImageTransform.Microsoft.Alpha(Opacity=5)"}.hcg_media_pc_mArticle .figure_frm .thumb_g{display:block;height:auto}.hcg_media_pc_mArticle .mglr_fig{padding:0}.hcg_media_pc_mArticle .mglr_fig .txt_caption{padding-right:15px;padding-left:15px}.hcg_media_pc_mArticle .origin_fig{display:table}.hcg_media_pc_mArticle .slide_fig{padding:0}.hcg_media_pc_mArticle .slide_fig .txt_caption{padding-right:15px;padding-left:15px}.hcg_media_pc_mArticle .slide_fig .inner_fig{overflow:hidden;position:relative;width:100%;height:auto}.hcg_media_pc_mArticle .slide_fig .btn_flick{position:absolute;top:0;bottom:47px;width:46px}.hcg_media_pc_mArticle .slide_fig .img_fig{display:inline-block;overflow:hidden;width:19px;height:33px;margin-top:28px;background:url(//m1.daumcdn.net/img-media/storyfunding/m320/img_fig.png) no-repeat;text-indent:-9999px}.hcg_media_pc_mArticle .slide_fig .btn_prev{left:0}.hcg_media_pc_mArticle .slide_fig .ico_prev{background-position:-1px -1px}.hcg_media_pc_mArticle .slide_fig .btn_next{right:0}.hcg_media_pc_mArticle .slide_fig .ico_next{background-position:-22px -1px}.hcg_media_pc_mArticle .slide_fig .page_count{position:absolute;right:14px;bottom:15px;min-height:15px;padding:1px 7px;border:1px solid rgba(0,0,0,0.1);border-radius:15px;font-size:.65em;line-height:1.1;font-family:HelveticaNeue,Helvetica,sans-serif;color:#666;background-color:rgba(255,255,255,0.5);letter-spacing:0;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}.hcg_media_pc_mArticle .slide_fig .num_now{color:#333}.hcg_media_pc_mArticle .figure_frm:first-child{margin-top:0}.hcg_media_pc_mArticle .figure_frm+div{margin-top:40px}.hcg_media_pc_mArticle .figure_frm+.quote_frm{margin-top:30px}.hcg_media_pc_mArticle .video_frm{overflow:hidden;position:relative;width:100%;margin:32px 0 36px;padding-top:56.25%;clear:both}.hcg_media_pc_mArticle .video_frm .player_iframe{position:absolute;top:0;left:0;width:100%;height:100%}.hcg_media_pc_mArticle .video_frm+div{margin-top:40px}.hcg_media_pc_mArticle .video_frm:first-child{margin-top:0}.hcg_media_pc_mArticle .aud ...
# .hc_news_pc_cEtc_realtime_news_201904 .thumb_g{width:285px;height:160px}
# .hc_news_pc_cSub_printButton .btn_print:focus{border-color:#000;background-color:#000}.hc_news_pc_cSub_printButton .btn_print:focus .ico_newsview{background-position:-60px -40px}
# .hc_news_pc_cSub_shareButtons .social_comm_p{position:absolute;z-index:1000}.hc_news_pc_cSub_shareButtons .social_comm_p .img_social{display:block;overflow:hidden;font-size:0;background:url(//t1.daumcdn.net/daumtop_deco/images/common/social/img_social_180425.png) no-repeat 0 0;text-indent:-9999px}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_comm_p{overflow:hidden;position:relative;border:1px solid #e2e2e2;font-size:12px;color:#222;background-color:#fff;letter-spacing:-0.025em}.hc_news_pc_cSub_shareButtons .social_comm_p .btn_close{position:absolute;top:7px;right:7px;width:24px;height:24px}.hc_news_pc_cSub_shareButtons .social_comm_p .ico_close{width:14px;height:14px;margin:5px;background-position:-150px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .share_layer{position:relative;width:289px;min-height:253px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns{overflow:hidden;margin:29px 15px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns li{float:left;width:86px;height:86px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .link_sns{display:block;text-align:center;text-decoration:none}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .link_sns .img_social{width:48px;height:48px;margin:0 auto}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .tit_sns{display:block;margin-top:7px;font-weight:normal;line-height:16px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_ks{background-position:0 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_fb{background-position:-50px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_tw{background-position:-100px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_cafe{background-position:0 -50px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_mail{background-position:-50px -50px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_kt{background-position:0 -100px}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl{margin:1px 29px}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl .link_copyurl{display:block;overflow:hidden;position:relative;height:25px;line-height:25px;border:1px solid #d0d0d0;background-color:#f8f8f8;text-decoration:none}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl .txt_url{display:block;overflow:hidden;padding:0 60px 0 10px;color:#2695f8;white-space:nowrap;text-overflow:ellipsis}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl .txt_copy{position:absolute;top:0;right:0;width:53px;height:25px;border-left:1px solid #d0d0d0;background-color:#fff;text-align:center}.hc_news_pc_cSub_shareButtons .social_comm_p .copyurl_layer{width:254px;height:78px;text-align:center}.hc_news_pc_cSub_shareButtons .social_comm_p .inner_copyurl{display:table;width:100%;height:100%}.hc_news_pc_cSub_shareButtons .social_comm_p .inner_copyurl .desc_copyurl{display:table-cell;padding:18px 0 17px;line-height:19px;vertical-align:middle}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl_type2 .tf_url{display:block;width:210px;height:25px;padding:0 10px;border:0 none;color:#2695f8;background-color:transparent}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl_type2 .desc_tip{padding:13px 0;line-height:18px;color:#888;text-align:center;letter-spacing:0}.hc_news_pc_cSub_shareButtons .social_comm_p{top:40px;right:-10px}.hc_news_pc_cSub_shareButtons .sns_comm_p .btn_close{display:none}@media only screen and (-webkit-min-device-pixel-ratio:1.5),only screen and (min-device-pixel-ratio:1.5),only screen and (min-resolution:144dpi),only screen and (min-resolution:1.5dppx){.hc_news_pc_cSub_shareButtons .social_comm_p .img_social{background-image:url(//t1.daumcdn.net/daumtop_deco/images/common/social/rtn/img_social_180425.png);background-size:170px 160px}}
# .hc_gallery_icon_on_image news_view figure .direct_view{overflow:hidden;position:absolute;left:50%;height:44px}
# .hc_news_pc_mAside_phototv .thumb_g{width:144px;height:140px}
#
# </style>
# <!--[if IE ]>
# 	<script type="text/javascript" src="//t1.daumcdn.net/harmony_static/view_cloud/2019/07/01/183439/libIEPolyfills.js"></script>
# 	<![endif]-->
# <!--[if lt IE 9]>
# 	<link type="text/css" rel="stylesheet" href="https://t1.daumcdn.net/harmony_static/view_cloud/2017/01/02/142101/media/ie8.css">
#     <link rel="stylesheet" type="text/css" href="https://t1.daumcdn.net/section/election/ticker.ie8.min.css">
# 	<![endif]-->
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="https://t1.daumcdn.net/news/202003/21/segye/20200321131028933jaao.jpg" property="twitter:image"/>
# <meta content="https://news.v.daum.net/v/20200321131028118" property="dg:uoc:pcUrl:"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20200321131028118" property="al:android:url"/>
# <meta content="net.daum.android.daum" property="al:android:package"/>
# <meta content="다음앱" property="al:android:app_name"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20200321131028118" property="al:ios:url"/>
# <meta content="365494029" property="al:ios:app_store_id"/>
# <meta content="다음앱" property="al:ios:app_name"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20200321131028118" property="twitter:app:url:googleplay"/>
# <meta content="net.daum.android.daum" property="twitter:app:id:googleplay"/>
# <meta content="다음앱" property="twitter:app:name:googleplay"/>
# <meta content="KR" property="twitter:app:country"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20200321131028118" property="twitter:app:url:iphone"/>
# <meta content="365494029" property="twitter:app:id:iphone"/>
# <meta content="다음앱" property="twitter:app:name:iphone"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20200321131028118" property="twitter:app:url:ipad"/>
# <meta content="365494029" property="twitter:app:id:ipad"/>
# <meta content="다음앱" property="twitter:app:name:ipad"/>
# <meta content="다음 뉴스" property="og:site_name"/>
# <meta content="당 간판이 어째.. 국민 마음과 비례 않는 비례대표" property="og:title"/>
# <meta content="20200321131028" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="https://news.v.daum.net/v/20200321131028118" property="og:url"/>
# <meta content="https://img1.daumcdn.net/thumb/S1200x630/?fname=https://t1.daumcdn.net/news/202003/21/segye/20200321131028933jaao.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="https://i1.daumcdn.net/img-media/mobile/meta/news.png?date=20170525" property="og:image"/>
# <meta content="4·15 총선에서 각 당의 얼굴인 비례대표가 잇단 논란에 휩싸였다. 당의 간판인 ‘비례 1번’을 놓고 잡음이 터져 나오면서도 당의 검증 과정에도 의문이 제기되고 있다. 당선권인 상위 순번에서도 논란이 불거진 후보가 적지 않다.  ‘대리게임’으로 도덕성 논란에 휩싸였다 재신임을 받은 정의당 비례대표 후보인 류호정 씨가 16일 국회 정론관에서 입장을 밝히" property="og:description"/>
# <meta content="news" property="dg:uoc:svc"/>
# <meta content="20200321131028118" property="dg:uoc:uid"/>
# <meta content="article" property="dg:uoc:sc"/>
# <meta content="https://news.v.daum.net/v/20200321131028118" property="dg:uoc:pcUrl"/>
# <meta content="https://news.v.daum.net/v/20200321131028118?f=m" property="dg:uoc:mUrl"/>
# <meta content="media.daum.net" name="svcdomain"/>
# <!-- 다음탑 코코크러쉬 메타데이터 -->
# <meta content="https://news.v.daum.net/v/20200321131028118" name="plink"/>
# <meta content="https://news.v.daum.net/v/20200321131028118" property="article:txid"/>
# <meta content="세계일보" name="article:media_name"/>
# <meta content="다음 뉴스" name="article:service_name"/>
# <meta content="20200321131028" property="article:published_time"/>
# <meta content="20200321201358" property="article:modified_time"/>
# <meta content="https://news.v.daum.net/v/20200321131028118?f=m" property="article:mobile_url"/>
# <meta content="https://news.v.daum.net/v/20200321131028118?f=m" property="article:mobile_view_url"/>
# <meta content="http://m.media.daum.net/" property="article:mobile_service_home"/>
# <meta content="https://news.v.daum.net/v/20200321131028118" property="article:pc_url"/>
# <meta content="https://news.v.daum.net/v/20200321131028118" property="article:pc_view_url"/>
# <meta content="http://media.daum.net/" property="article:pc_service_home"/>
# <meta content="https://v.kakao.com/v/20200321131028118" property="article:talk_channel_view_url"/>
# </head>
# <body>
# <div id="kakaoIndex">
# <a href="#kakaoBody">본문 바로가기</a>
# <a href="#kakaoGnb">메뉴 바로가기</a>
# </div>
# <div class="newsview_media" id="kakaoWrap">
# <!-- 2018-09-20 영어,인도네시아어 번역일 경우, lang_type1 클래스 추가 -->
# <!-- 2018-09-20 중국어, 일본어 번역일 경우, lang_type2 클래스 추가 -->
# <!-- 2018-09-11-v2  2018-09-20 베트남어 번역일 때 lang_type3 클래스 추가 -->
# <div class="#gnb #default hcg_media_pc_kakaoHead" id="kakaoHead" role="banner">
# <div class="head_media">
# <h1> <a class="link_daum" href="https://www.daum.net/"> <img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/> </a> <a href="https://media.daum.net/" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1>
# <strong class="screen_out">관련서비스</strong>
# <ul id="kakaoRelServices">
# <li><a class="link_services link_services1" href="https://media.daum.net/entertain/"><span class="ir_wa">연예</span></a></li>
# <li><a class="link_services link_services2" href="https://sports.media.daum.net/sports/"><span class="ir_wa">스포츠</span></a></li>
# </ul>
# <h2 class="screen_out">검색</h2>
# <div class="search_news" id="search_news">
# <form action="https://search.daum.net/search" id="kakaoSearch" method="get" name="kakaoSearch">
# <fieldset class="fld_inside">
# <legend class="screen_out">검색어 입력폼</legend>
# <div class="box_searchbar">
# <label class="lab_search" for="qVal">통합검색</label>
# <input name="nil_profile" type="hidden" value="search"/>
# <input name="nil_src" type="hidden" value="media"/>
# <input name="DA" type="hidden" value="23A"/>
# <input name="rtmaxcoll" type="hidden" value="NNS"/>
# <input autocomplete="off" class="tf_keyword" id="qVal" name="q" spellcheck="false" title="검색어 입력" type="text" value=""/>
# <button class="btn_search" id="kakaoBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </fieldset>
# <div class="wrap_suggestBox" id="wrap_suggestBox">
# <div class="suggestBox box_sub" id="suggestBox">
# <div class="baseBox bg" style="display: none"></div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div id="kakaoGnb" role="navigation">
# <div class="inner_gnb">
# <h2 class="screen_out">뉴스 메인메뉴</h2>
# <ul class="gnb_comm" data-category="politics">
# <li class="home"><a class="link_gnb link_gnb1" href="https://media.daum.net/"><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="society"><a class="link_gnb link_gnb2" href="https://media.daum.net/society/"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <!-- 현재페이지에 on클래스 추가  -->
# <li class="politics"><a class="link_gnb link_gnb3" href="https://media.daum.net/politics/"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="economic"><a class="link_gnb link_gnb4" href="https://media.daum.net/economic/"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="foreign"><a class="link_gnb link_gnb5" href="https://media.daum.net/foreign/"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="culture"><a class="link_gnb link_gnb6" href="https://media.daum.net/culture/"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="digital"><a class="link_gnb link_gnb7" href="https://media.daum.net/digital/"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="popular"><a class="link_gnb link_gnb8" href="https://media.daum.net/ranking/popular/"><span class="ir_wa">랭킹</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="series editorial"><a class="link_gnb link_gnb9" href="https://media.daum.net/series/"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="photo"><a class="link_gnb link_gnb10" href="https://media.daum.net/photo/"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="tv"><a class="link_gnb link_gnb11" href="https://media.daum.net/tv/"><span class="ir_wa">TV</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_etc">
# <ul class="gnb_with">
# <li><a class="link_gnb link_gnb1" href="https://media.daum.net/1boon/"><span class="ir_wa">1boon</span></a></li>
# <li><a class="link_gnb link_gnb2" href="//gallery.v.daum.net/p/home"><span class="ir_wa">갤러리</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_weather hc_news_pc_kakaoHead_gnbWeather">
# <strong class="screen_out">날씨 정보</strong>
# <div id="gnb_weather">
# <ul class="list_weather" data-nightyn="N">
# <!-- 69px씩 이동합니다 / 밤일 경우, type_night 클래스 추가 -->
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=서울%20날씨"> <span class="ico_weather ico_weather1">서울</span> <span class="txt_weather">서울 <span class="num_heat">16</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=수원%20날씨"> <span class="ico_weather ico_weather1">수원</span> <span class="txt_weather">수원 <span class="num_heat">15</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=인천%20날씨"> <span class="ico_weather ico_weather1">인천</span> <span class="txt_weather">인천 <span class="num_heat">16</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대구%20날씨"> <span class="ico_weather ico_weather1">대구</span> <span class="txt_weather">대구 <span class="num_heat">20</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대전%20날씨"> <span class="ico_weather ico_weather1">대전</span> <span class="txt_weather">대전 <span class="num_heat">19</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=광주%20날씨"> <span class="ico_weather ico_weather1">광주</span> <span class="txt_weather">광주 <span class="num_heat">19</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=부산%20날씨"> <span class="ico_weather ico_weather1">부산</span> <span class="txt_weather">부산 <span class="num_heat">13</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울산%20날씨"> <span class="ico_weather ico_weather1">울산</span> <span class="txt_weather">울산 <span class="num_heat">12</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울릉/독도%20날씨"> <span class="ico_weather ico_weather1">울릉/독도</span> <span class="txt_weather">울릉/독도 <span class="num_heat">8</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=춘천%20날씨"> <span class="ico_weather ico_weather1">춘천</span> <span class="txt_weather">춘천 <span class="num_heat">18</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=강릉%20날씨"> <span class="ico_weather ico_weather1">강릉</span> <span class="txt_weather">강릉 <span class="num_heat">12</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=백령%20날씨"> <span class="ico_weather ico_weather1">백령</span> <span class="txt_weather">백령 <span class="num_heat">9</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=청주%20날씨"> <span class="ico_weather ico_weather1">청주</span> <span class="txt_weather">청주 <span class="num_heat">16</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=전주%20날씨"> <span class="ico_weather ico_weather1">전주</span> <span class="txt_weather">전주 <span class="num_heat">18</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=목포%20날씨"> <span class="ico_weather ico_weather1">목포</span> <span class="txt_weather">목포 <span class="num_heat">12</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=여수%20날씨"> <span class="ico_weather ico_weather1">여수</span> <span class="txt_weather">여수 <span class="num_heat">15</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=제주%20날씨"> <span class="ico_weather ico_weather2">제주</span> <span class="txt_weather">제주 <span class="num_heat">15</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=안동%20날씨"> <span class="ico_weather ico_weather1">안동</span> <span class="txt_weather">안동 <span class="num_heat">20</span> <span class="txt_heat">℃</span> </span> </a> </li>
# <li> <a class="link_cont" href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=창원%20날씨"> <span class="ico_weather ico_weather1">창원</span> <span class="txt_weather">창원 <span class="num_heat">19</span> <span class="txt_heat">℃</span> </span> </a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bar_progress" id="barProgress"></div>
# </div>
# <hr class="hide hcg_media_pc_kakaoHead"/>
# <div class="cont_view" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">정치</h2>
# <div class="hcg_media_pc_cSub" id="cSub">
# <div class="head_view">
# <em class="info_cp"> <a class="link_cp #body #cplogo" href="http://www.segye.com/" target="_blank"> <img alt="세계일보" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_segye.gif"/> </a> </em>
# <h3 class="tit_view" data-translation="">당 간판이 어째.. 국민 마음과 비례 않는 비례대표</h3>
# <span class="info_view"> <span class="txt_info">정은나리</span> <span class="txt_info">입력 2020.03.21. 13:10</span> <span class="txt_info">수정 2020.03.21. 20:13</span> <button class="emph_g2 link_cmt" id="alexCounter">댓글 <span class="alex-count-area">0</span>개</button> </span>
# <div class="util_view">
# <!-- 2018-08-31-v2 버튼 순서 변경 / 자동요약 - TTS - 번역 - 공유 - 글씨크기 - 인쇄 순 -->
# <!-- 자동요약 -->
# <!-- TTS -->
# <div class="btn_util tts_btn hc_news_pc_cSub_tts">
# <button aria-expanded="false" class="btn_set btn_tts" type="button"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_tts">
# <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
# <ul class="list_set list_tts">
# <li> <input class="screen_out" id="ttsGenderMale" name="ttsGender" type="radio" value="Male"/> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
# <li> <input class="screen_out" id="ttsGenderFemale" name="ttsGender" type="radio" value="Female"/> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
# </ul>
# <ul class="list_set list_tts list_ttsspeed">
# <li> <input class="screen_out" id="ttsSpeedSlow" name="ttsSpeed" type="radio" value="slow"/> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
# <li> <input class="screen_out" id="ttsSpeedNormal" name="ttsSpeed" type="radio" value="normal"/> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
# <li> <input class="screen_out" id="ttsSpeedFast" name="ttsSpeed" type="radio" value="fast"/> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
# </ul>
# </div>
# </div>
# <audio id="ttsPlayer" preload="none" style="display:none"></audio>
# </div>
# <!-- 번역 -->
# <div class="btn_util translate_btn hc_news_pc_cSub_translateButtons">
# <!-- 활성화시 aria-expanded="true" / 비활성화시 aria-expanded="false" 추가 -->
# <button aria-expanded="false" class="btn_set btn_translate #util #translate #set" type="button"><span class="ico_newsview">번역 설정</span></button>
# <div class="wrap_translatelayer">
# <div class="layer_util layer_translate">
# <strong class="tit_translate">번역<span class="ico_newsview">beta</span>
# <!-- 2018-09-04 추가--></strong>
# <p class="desc_translate txt_newsview">Translated by <a class="link_kakaoi #util #translate #kakaoi_link" href="https://kakao.ai/" target="_blank">kakao i</a></p>
# <strong class="screen_out">번역할 언어 선택</strong>
# <ul class="list_lang">
# <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
# <li> <button class="btn_lang btn_ch #util #translate #lang_cn" name="cn" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
# <li> <button class="btn_lang btn_jp #util #translate #lang_jp" name="jp" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
# <li> <button class="btn_lang btn_ind #util #translate #lang_id" name="id" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
# <li> <button class="btn_lang btn_viet #util #translate #lang_vi" name="vi" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
# <li> <button class="btn_lang btn_ko #util #translate #lang_kr" name="kr" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="hc_translator" style="display:none;"></div>
# <!-- 공유 -->
# <div class="btn_util share_btn hc_news_pc_cSub_shareButtons">
# <button aria-expanded="false" class="btn_set btn_share" id="rSocialShareButton"> <span class="ico_newsview">공유</span> </button>
# <div id="rSocialShareLayerContainer"></div>
# </div>
# <!-- 글씨크기 -->
# <div class="font_btn btn_util hc_news_pc_cSub_fontSizeController">
# <button aria-expanded="false" class="btn_set btn_font" type="button"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_font">
# <strong class="screen_out">글자 크기 조절 레이어</strong>
# <ul class="list_set list_font">
# <li> <input class="screen_out" id="inpFont17" name="inpFont" type="radio" value="17"/> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont18" name="inpFont" type="radio" value="18"/> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont19" name="inpFont" type="radio" value="19"/> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont20" name="inpFont" type="radio" value="20"/> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont21" name="inpFont" type="radio" value="21"/> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
# </ul>
# </div>
# </div>
# <!-- // font 팝업 레이어 -->
# </div>
# <!-- 인쇄 -->
# <div class="btn_util hc_news_pc_cSub_printButton">
# <button class="btn_print" type="button"> <span class="ico_newsview">인쇄하기 새창열림</span> </button>
# </div>
# </div>
# </div>
# </div>
# <div id="cMain">
# <div class="hcg_media_pc_mArticle" id="mArticle">
# <!-- 바꿔치기 -->
# <!-- 언론중재법 -->
# <!-- 번역 안내 -->
# <div class="status_view" id="translateNotice" style="display:none;">
# <span class="notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</span>
# <span class="notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</span>
# <span class="notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</span>
# <span class="notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</span>
# <span class="notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</span>
# </div>
# <div class="news_view" style="font-size:17px">
# <strong class="summary_view" data-translation="">'불공정 논란' 휩싸인 정의당 1번..'부정수급' 피소된 민주당 1번 / '경력 부족' 김정현 변호사·'MBC 인사불이익' 신동호 전 국장, 야당 비례 당선권 배치돼 '논란'</strong>
# <div class="article_view" data-translation-body="" id="harmonyContainer">
# <section dmcf-sid="jABa1Jt2cC">
# <p dmcf-pid="jUsVK9dS3P" dmcf-ptype="general">4·15 총선에서 각 당의 얼굴인 비례대표가 잇단 논란에 휩싸였다. 당의 간판인 ‘비례 1번’을 놓고 잡음이 터져 나오면서도 당의 검증 과정에도 의문이 제기되고 있다. 당선권인 상위 순번에서도 논란이 불거진 후보가 적지 않다. </p>
# <figure class="figure_frm origin_fig" dmcf-pid="j2n27pS7Gl" dmcf-ptype="figure">
# <p class="link_figure"><img alt="‘대리게임’으로 도덕성 논란에 휩싸였다 재신임을 받은 정의당 비례대표 후보인 류호정 씨가 16일 국회 정론관에서 입장을 밝히고 있다. 연합뉴스" class="thumb_g_article" data-align="center" dmcf-mid="jKfiYkwFwK" dmcf-mtype="image" height="351" src="https://t1.daumcdn.net/news/202003/21/segye/20200321131028933jaao.jpg" storyid="9886fff5-e99f-43e0-808c-0448c370c7eb" width="512"/></p>
# <figcaption class="txt_caption default_figure">
#            ‘대리게임’으로 도덕성 논란에 휩싸였다 재신임을 받은 정의당 비례대표 후보인 류호정 씨가 16일 국회 정론관에서 입장을 밝히고 있다. 연합뉴스
#           </figcaption>
# </figure>
# <div dmcf-pid="jeidCyoual" dmcf-ptype="general">
#            ◆ ‘비례 1번’ 맞아?…당 대표주자, 도덕성 논란 중심에
#          </div>
# <p dmcf-pid="jMvdN8Zl2A" dmcf-ptype="general">정의당은 ‘대리게임’을 논란에 휩싸였던 류호정씨를 비례후보 1번에 재신임하면서 시끄럽다. 이로 인해 불거진 ‘불공정’ 논란은 정의당에 대한 매서운 비판의 빌미를 제공했다. 당의 정체성을 드러내는 ‘비례 1번’의 상징성 때문에 정의당이 불공정으로 대표되는 ‘대리게임’을 옹호하는 것이냐는 논란으로 이어졌다. 특히 불공정 이슈에 민감한 청년층은 류 후보에 대한 반감을 드러내는 상황이다.</p>
# <p dmcf-pid="jf2N1wOx2j" dmcf-ptype="general">야당의 비판도 쏟아졌다. 미래통합당 하태경 의원은 “정의당의 당노선을 불공정으로 채택한 것이나 다름없다”고 비판했다. 민주당 공천관리위원으로 영입된 프로게이머 출신 황희두씨는 “청년들에게 매우 민감한 문제”라며 여전히 ‘고작 게임’ 취급을 받는 현실에 분노하는 것”이라고 지적했다. 그러면서 “시대가 빠르게 변하고 있음을 인지하지 못하면 어떤 청년 정책을 전할지라도 전혀 공감을 얻지 못할 것”이라고 날을 세웠다.</p>
# <figure class="figure_frm origin_fig" dmcf-pid="juuIaK3Niy" dmcf-ptype="figure">
# <p class="link_figure"><img alt="더불어민주당 1호 영입인재 최혜영 강동대 교수. 연합뉴스 " class="thumb_g_article" data-align="center" dmcf-mid="jRMcfuYroV" dmcf-mtype="image" height="343" src="https://t1.daumcdn.net/news/202003/21/segye/20200321131029072cwus.jpg" storyid="fe5ceef2-e914-4f32-92f7-3bd5f7650dcf" width="512"/></p>
# <figcaption class="txt_caption default_figure">
#            더불어민주당 1호 영입인재 최혜영 강동대 교수. 연합뉴스
#           </figcaption>
# </figure>
# <div dmcf-pid="jlbnnTcCjy" dmcf-ptype="general">
#            더불어민주당이 1호 영입 인재로 ‘비례 1번’으로 내세웠던 최혜영 강동대 교수는 혼인신고를 의도적으로 늦춰 8년간 기초생활비 등 3000여만원을 부정 수급했다는 논란에 휩싸였다. 유튜브 채널 ‘가로세로연구소’는 사기 및 기초생활보장법 위반 혐의 등으로 최 교수와 남편 정모 씨를 서울중앙지검에 고발했다. 최 교수는 지난 17일 MBC라디오 인터뷰에서 ‘관련 의혹에 대해 전혀 부끄러움이 없느냐’는 질문에 “이익을 취하려고 또는 의도한 것이 절대 아니기 때문에 지금은 그렇다”라고 답했다.
#          </div>
# <p dmcf-pid="jTfxVTtPAf" dmcf-ptype="general">미래한국당 1번에 오른 조수진 전 동아일보 논설위원은 최근까지 여권 인사들을 강경한 표현으로 비판해오다 곧바로 야당 최상위 순번으로 정치권에 직행한 것을 두고 적절성 논란이 불거졌다.</p>
# <figure class="figure_frm origin_fig" dmcf-pid="jH88rzYu8T" dmcf-ptype="figure">
# <p class="link_figure"><img alt="조수진 전 동아일보 논설위원. 채널A 방송화면 캡처" class="thumb_g_article" data-align="center" dmcf-mid="j2hfZMADvn" dmcf-mtype="image" height="265" src="https://t1.daumcdn.net/news/202003/21/segye/20200321131029218fnxt.jpg" storyid="288a92bc-22c3-426b-8067-de11a64a6c47" width="455"/></p>
# <figcaption class="txt_caption default_figure">
#            조수진 전 동아일보 논설위원. 채널A 방송화면 캡처
#           </figcaption>
# </figure>
# <div dmcf-pid="jSCQMQHC7T" dmcf-ptype="general">
#            ◆경력 없는 신참 변호사가 비례후보? 법조계도 ‘의아’
#          </div>
# <p dmcf-pid="jbhWp2K7bD" dmcf-ptype="general">미래한국당이 모(母)정당인 미래통합당과 ‘공천 파동’으로 지도부와 공천관리원장이 바뀌면서 비례대표 명단 수정이 불가피해진 가운데 비례대표 5번에 이름을 올렸던 김정현 변호사, 14번 신동호 전 MBC 아나운서 국장의 순번 재조정 가능성도 제기된다.</p>
# <p dmcf-pid="jdRWQwCG94" dmcf-ptype="general">김 변호사는 로스쿨 졸업 후 변호사 경력이 11개월에 불과한데 당선권인 5번에 배치돼 논란이 일었다. 지난해 4월 변호사시험에 합격한 뒤 이제 수습 기간을 끝낸 법률사무소 공정 소속 변호사다. 서울대 로스쿨 등 학력 외에는 이렇다 할 경력이 없는데 최상위 비례후보에 오른 것을 두고 법조계에서도 의아하다는 지적이 나왔다.</p>
# <p dmcf-pid="jR0YXsgaHi" dmcf-ptype="general">이명박·박근혜정부 당시 MBC 간판 아나운서로 활약한 신 전 국장은 지난 2018년 사내 블랙리스트에 기반해 아나운서들에게 인사 불이익을 가했다는 이유 등으로 정직 6개월 징계를 받았다. 이후 신 국장은 법인카드 사용 문제로 다시 정직 6개월 처분을 받았다. 1000만원 이상 국장 법인카드 사용 액수에 대해 소명 및 변상하라는 감사의 요구를 제대로 이행하지 않은 것으로 알려져 논란이 일었다.</p>
# <p dmcf-pid="jhU5Zp6JDC" dmcf-ptype="general">신 전 국장은 2018년 11월 MBC를 상대로 서울서부지법에 징계무효확인소송을 제기했고, 현재 해당 재판이 진행 중이다.</p>
# <figure class="figure_frm origin_fig" dmcf-pid="j0jlK0ZuWg" dmcf-ptype="figure">
# <p class="link_figure"><img alt="김의겸 전 청와대 대변인(왼쪽)·최강욱 전 청와대 공직기강비서관" class="thumb_g_article" data-align="center" dmcf-mid="jOXS26OClE" dmcf-mtype="image" height="300" src="https://t1.daumcdn.net/news/202003/21/segye/20200321131029377osvf.jpg" storyid="09d2c8bd-748c-4405-82ab-bba7a4fca1eb" width="500"/></p>
# <figcaption class="txt_caption default_figure">
#            김의겸 전 청와대 대변인(왼쪽)·최강욱 전 청와대 공직기강비서관
#           </figcaption>
# </figure>
# <div dmcf-pid="jR2xvteJe1" dmcf-ptype="general">
#            ◆‘투기논란’ 김의겸· ‘조국 비리 혐의 연루’ 최강욱 열린민주당으로
#          </div>
# <p dmcf-pid="jHeUXYcioh" dmcf-ptype="general">정봉주 전 더불어민주당 의원과 손혜원 무소속 의원이 주도하는 열린민주당은 지난 20일 오후 발표한 총선 비례대표 후보 20명을 발표했다. 여기에는 최강욱 전 청와대 공직기강비서관, 김의겸 전 청와대 대변인이 명단에 포함됐다. 조 전 장관 시절 검찰개혁추진단장이었던 황희석 전 법무부 인권국장, 손혜원 의원실 보좌관 출신인 김성회 정치연구소 싱크와이 소장도 비례 후보에 이름을 올렸다.</p>
# <p dmcf-pid="jA1W2VPyxb" dmcf-ptype="general">김 전 대변인은 당초 더불어민주당 후보로 전북 군산 공천을 신청했지만, 흑석동 재개발지역 상가 투기논란으로 후보 적격 판정이 미뤄지자 불출마를 선언하고 탈당하고 열린민주당에 입당했다.</p>
# <p dmcf-pid="jNWSi2pmpq" dmcf-ptype="general">최 전 비서관은 조국 전 법무부장관 아들에게 허위 인턴 증명서를 발급해준 혐의로 재판에 넘겨진 상태다. 그는 공직선거법상 비례대표 국회의원 선거에 입후보하는 공무원의 사직기한인 지난 16일 사의를 표명했다. 최 전 비서관은 이날 페이스북에 “열린민주당과 함께 개혁을 완성하는 희망의 바다로 끈질기게 흐르고자 한다”면서 “시민의 부름을 받았니 소명을 다하겠다. 거악과 맞서며 포기하지 않겠다”고 밝혔다.</p>
# <p dmcf-pid="jqsnoOed1G" dmcf-ptype="general">열린민주당은 오는 22~23일 온라인 투표를 거쳐 비례대표 순번을 결정한다. 열린민주당이 비례연합정당 ‘더불어시민당’에 참여하는 민주당과 독자노선을 걷는다고 밝혔지만, 더불어시민당이 친문(親文) 성향이 강해 총선 이후 통합할 것이라는 전망도 나온다.</p>
# <p dmcf-pid="jzQ3AqtJyq" dmcf-ptype="general">정은나리 기자 jenr38@segye.com</p>
# </section>
# </div>
# </div>
# <div class="foot_view">
# <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
# </div>
# <div class="relate_tag hc_news_pc_mArticle_relatedTags">
# <strong class="screen_out">관련 태그</strong>
# </div>
# <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
# <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
# <!-- MCCP-856 연재 영역 수정 -->
# <ul class="list_series">
# </ul>
# <!-- //MCCP-856 연재 영역 수정 -->
# <a class="link_more #body #series_more" href="#none">더보기</a>
# </div>
# <div class="copyright_view">
# <span class="txt_copyright">ⓒ 세계일보 &amp; Segye.com, 무단 전재 및 재배포 금지</span>
# <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
# <link href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css" rel="stylesheet" type="text/css"/>
# <div class="btn_empathy_pc" id="likeButton">
# </div>
# </div>
# </div>
# <!-- 언론사 관련기사(주요뉴스) -->
# <div class="cp_view">
# <strong class="tit_cp">세계일보 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
# <ul class="list_relate">
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.segye.com/r.jsp?aid=20200315505890?utm_source=daum&amp;utm_medium=news&amp;utm_campaign=portal" target="_blank">[단독] ‘미스터트롯’, 한 참가자…PD로부터 압력 받았다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.segye.com/r.jsp?aid=20200319505776?utm_source=daum&amp;utm_medium=news&amp;utm_campaign=portal" target="_blank">“사람들이 어쩌면 그럴 수 있나” 박근혜 격노하며 언급한 ‘두번 칼질’ 의미는</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.segye.com/r.jsp?aid=20200302504346?utm_source=daum&amp;utm_medium=news&amp;utm_campaign=portal" target="_blank">“文대통령님, 하야해주세요”…고교생 청와대 청원 화제</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.segye.com/r.jsp?aid=20200319519889?utm_source=daum&amp;utm_medium=news&amp;utm_campaign=portal" target="_blank">성착취 동영상 공유 혐의 '박사'는 얼굴을 꽁꽁 싸맸다</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.segye.com/r.jsp?aid=20200312510425?utm_source=daum&amp;utm_medium=news&amp;utm_campaign=portal" target="_blank">"씻겨줄려고"…만취여성 옷 벗긴 20대 실형</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.segye.com/r.jsp?aid=20200318519721?utm_source=daum&amp;utm_medium=news&amp;utm_campaign=portal" target="_blank">“조국 딸, KIST 인턴 때 엎드려 잠만 잤다더라” 교수의 증언</a></li>
# <li><a class="link_txt #body #outmedia #related_list" data-type="rss" href="http://www.segye.com/r.jsp?aid=20200312517465?utm_source=daum&amp;utm_medium=news&amp;utm_campaign=portal" target="_blank">“면역력 높아 괜찮아”… 여전히 클럽·술집 몰리는 2030</a></li>
# </ul>
# </div>
# <div id="alex-scroll-area"></div>
# <ins class="daum_ddn_area recomm_ad hc_news_pc_mArticle_recommend_ad" data-ad-height="90" data-ad-onfail="cmRenderFailCallBack" data-ad-unit="DAN-1jezdswwiit7q" data-ad-width="658" style="display:block; width: 658px; text-decoration: none; min-width: 658px;"></ins>
# <div class="cmt_news cmt_view">
# <div class="news_notice hc_news_pc_mArticle_news_notice" id="newsviewNotice">
# <strong class="tit_notice">공지</strong>
# <span class="txt_notice"><a class="link_txt" href="https://magazine.kakao.com/docs/5e54e7a92007421c9da29a13">카카오가 댓글 이용자 보호에 나섭니다</a></span>
# </div>
# <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20200321131028118" data-show-mask-alert="true" data-sort="R" data-use-attachment="false" data-use-emoticon="true" data-use-fold="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-social-share="true" id="alex-area">
# </div>
# </div>
# </div>
# </div>
# <div class="hcg_media_pc_mAside" id="mAside">
# <div class="hc_news_pc_cSub_bnr_130" style="position:relative">
# <div class="bnr_130">
# <ins class="daum_ddn_area" data-ad-height="250" data-ad-type="P" data-ad-unit="05d90" data-ad-width="130" id="RIGHT_SPACE_BANNER" name="RIGHT_SPACE_BANNER"></ins>
# </div>
# </div>
# <!-- //130 배너 -->
# <ins class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideTopAd" data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" style="display:block;width:250px;height:250px;"></ins>
# <div class="hc_news_pc_mAside_popular_news">
# <div class="aside_g aside_popular" data-react-checksum="-1707868630" data-reactid=".fo2gw7f3fh">
# <h3 class="txt_newsview" data-reactid=".fo2gw7f3fh.0">많이본 뉴스</h3>
# <ul class="tab_aside tab_media" data-reactid=".fo2gw7f3fh.1">
# <li class="on" data-reactid=".fo2gw7f3fh.1.0"><a class="link_tab link_tab2 #right #popular_tab #news" data-reactid=".fo2gw7f3fh.1.0.0" href="#none">뉴스</a>
# <div class="cont_aside" data-reactid=".fo2gw7f3fh.1.0.1">
# <strong class="screen_out" data-reactid=".fo2gw7f3fh.1.0.1.0">뉴스</strong>
# <ol class="list_ranking #right #popular_news #news_list" data-reactid=".fo2gw7f3fh.1.0.1.1">
# <li data-reactid=".fo2gw7f3fh.1.0.1.1.$news1"><em class="num_newsview num1" data-reactid=".fo2gw7f3fh.1.0.1.1.$news1.0"><span data-reactid=".fo2gw7f3fh.1.0.1.1.$news1.0.0">1</span><span data-reactid=".fo2gw7f3fh.1.0.1.1.$news1.0.1">위</span></em><strong class="tit_g" data-reactid=".fo2gw7f3fh.1.0.1.1.$news1.1"><a class="link_txt @1" data-reactid=".fo2gw7f3fh.1.0.1.1.$news1.1.0" href="https://v.daum.net/v/20200322142821167">문대통령 "'사재기 없는 나라'는 국민 덕분..국민께 안도감 줘야"</a></strong></li>
# <li data-reactid=".fo2gw7f3fh.1.0.1.1.$news2"><em class="num_newsview num2" data-reactid=".fo2gw7f3fh.1.0.1.1.$news2.0"><span data-reactid=".fo2gw7f3fh.1.0.1.1.$news2.0.0">2</span><span data-reactid=".fo2gw7f3fh.1.0.1.1.$news2.0.1">위</span></em><strong class="tit_g" data-reactid=".fo2gw7f3fh.1.0.1.1.$news2.1"><a class="link_txt @2" data-reactid=".fo2gw7f3fh.1.0.1.1.$news2.1.0" href="https://v.daum.net/v/20200322144508597">이 와중에 日 '5만명 단체행사'..전세계 만류에도 "올림픽 강행"</a></strong></li>
# ...
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_common_new_tiara\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_cEtc\x22));"));
#
# (0,eval("(function(elements){\n(function($){\n\t\x27use strict\x27;\n\tvar summaryButton \x3d $(\x27.btn_summary\x27);\n\tvar summaryLayer \x3d $(\x27.util_summary\x27);\n\tvar shareButtonsLayer \x3d $(\x27#shareButtons\x27);\n\tvar summaryLayerStatus \x3d false;\n\n\tsummaryButton.on(\x27click\x27, function (ev) {\n\t\tsummaryLayerStatus \x3d !summaryLayerStatus;\n\n\t\tif (summaryLayerStatus) {\n\t\t\tshowLayer();\n\t\t} else {\n\t\t\thideLayer();\n\t\t}\n\t});\n\t\n\tsummaryLayer.focusin(function(event) {\n\t\tshowLayer();\n    });\n\tsummaryLayer.focusout(function(event) {\n\t\thideLayer();\n    });\n\n\tfunction showLayer () {\n\t\tsummaryLayer.addClass(\x27layer_open\x27);\n\t\tsummaryButton.attr(\x27aria-expanded\x27, true);\n\t\t$(window).on(\x27click\x27, checkLayer);\n\t}\n\n\tfunction hideLayer () {\n\t\tsummaryLayerStatus \x3d false;\n\t\tsummaryLayer.removeClass(\x27layer_open\x27);\n\t\tsummaryButton.attr(\x27aria-expanded\x27, false);\n\t}\n\n\tfunction checkLayer (ev) {\n\t\t\tif (summaryButton[0] \x3d\x3d ev.target || summaryButton[0].childNodes[0] \x3d\x3d ev.target) return false;\n\t\t\thideLayer();\n\t\t\t$(window).off(\x27click\x27, checkLayer);\n\t}\n})(jQuery);\n})(document.querySelectorAll(\x22.hcg_media_pc_cSub\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_head\x22));"));
#
# (0,eval("(function(elements){\n$(\x22.direct_link .btn_fold\x22).click(function() { \n\t$(\x22.direct_link\x22).toggleClass(\x22direct_open\x22);\n});\n\n})(document.querySelectorAll(\x22.hcg_media_pc_kakaoFoot\x22));"));
#
# (0,eval("(function(elements){\nvar kakaoWrap \x3d document.getElementById(\x27kakaoWrap\x27);\nvar categoryName \x3d $(elements).find(\x22.gnb_comm\x22).data(\x22category\x22);\ncategoryName \x3d window.layoutId \x3d\x3d \x27tvNews_pc\x27 ? \x27tv\x27 : categoryName;\n\n$(elements).find(\x22.gnb_comm li\x22).each(function() {\n  var $this \x3d $(this);\n  if($this.hasClass(categoryName)) {\n    $this.addClass(\x22on\x22).find(\x22.inner_bar\x22).css(\x22width\x22, \x22100%\x22);\n  }\n});\n\n//\uac80\uc0c9 suggest\n$.ajax({url:\x22https://search1.daumcdn.net/search/suggest_pc/suggest-1.2.16.min.js\x22, cache:true, dataType:\x22script\x22}).done(function(){\n  var suggestInstance \x3d new suggest.Suggest(document.getElementById(\x22search_news\x22), {\n    inputEl: \x27qVal\x27,\n    suggestBoxEl: \x27suggestBox\x27,\n    autoFocus: \x27NORMAL\x27,\n    suggestLimit: 10,\n    isReverse: false,\n    searchURL: \x27https://search.daum.net/search\x27,\n    APIServer: {\n      host: \x27https://dapi.kakao.com/suggest/v2/pc.json\x27,\n      apiType: suggest.Suggest.APITYPE.DAPISUGGEST,\n      appkey: \x27d7022f6ca2a04430ce1b97b922da58e8\x27,\n      queries: {\n        \x27mod\x27: \x27json\x27,\n        \x27code\x27: \x27utf_in_out\x27\n      }\n    }\n  });\n\n  // \ucd94\ucc9c \uac80\uc0c9\uc5b4 \ub9c8\uc6b0\uc2a4 \ud074\ub9ad\uc2dc \uac80\uc0c9\uc73c\ub85c \ubcf4\ub0b8\ub2e4.\n  suggestInstance.on(\x27click-item\x27, function () {\n    var $kakaoSearch \x3d $(\x27#kakaoSearch\x27);\n    $kakaoSearch.find(\x22input[name\x3d\x27DA\x27]\x22).val(\x2723B\x27);\n    $kakaoSearch.submit();\n  });\n\n  var queryInput \x3d $(\x22#qVal\x22);\n  queryInput.on(\x22focus\x22, function (e) {\n    e \x26\x26 e.preventDefault();\n    if (queryInput.val().length \x3e\x3d 0) {\n      queryInput.parent().addClass(\x22search_on\x22);\n    }\n  });\n  queryInput.on(\x22focusout\x22, function (e) {\n    e \x26\x26 e.preventDefault();\n    if (queryInput.val().length \x3d\x3d 0) {\n      queryInput.parent().removeClass(\x22search_on\x22);\n    }\n  });\n});\n\n})(document.querySelectorAll(\x22.hcg_media_pc_kakaoHead\x22));"));
#
# (0,eval("(function(elements){\n$(function(){\n    // click code\n    var click_codes \x3d [];\n    // GNB \n    click_codes.push({\n        \x22code\x22: \x22#logo\x22 , \x22selector\x22: \x22#kakaoHead \x3e div.head_media \x3e h1 \x3e a.link_daum\x22\n    });\n  \tclick_codes.push({\n        \x22code\x22: \x22#logo\x22 , \x22selector\x22: \x22.img_logo\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_news\x22 , \x22selector\x22: \x22#kakaoServiceLogo\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_enter\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(1) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_sports\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(2) \x3e a\x22\n    });\n  \tclick_codes.push({\n        \x22code\x22: \x22#gnb #default #service_lab\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(3) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #search\x22 , \x22selector\x22: \x22#kakaoBtnSearch\x22\n    });\n\n    click_codes.push({\n        \x22code\x22: \x22#media_home\x22 , \x22selector\x22: \x22.home \x3e a\x22\n    });\t\n    click_codes.push({\n        \x22code\x22: \x22#media_society\x22 , \x22selector\x22: \x22.society \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_politics\x22 , \x22selector\x22: \x22.politics \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_economic\x22 , \x22selector\x22: \x22.economic \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_foreign\x22 , \x22selector\x22: \x22.foreign \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_culture\x22 , \x22selector\x22: \x22.culture \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_digital\x22 , \x22selector\x22: \x22.digital \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_popular\x22 , \x22selector\x22: \x22.popular \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_series\x22 , \x22selector\x22: \x22.series \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_photo\x22 , \x22selector\x22: \x22.photo \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_tv\x22 , \x22selector\x22: \x22.tv \x3e a\x22\n    });\n\n    // \uc678\ubd80 \uc11c\ube44\uc2a4 \ub9c1\ud06c\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #media_1boon\x22 , \x22selector\x22: \x22#kakaoGnb \x3e div \x3e div \x3e ul \x3e li:nth-child(1) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #media_funding\x22 , \x22selector\x22: \x22#kakaoGnb \x3e div \x3e div \x3e ul \x3e li:nth-child(2) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #widget_weather\x22 , \x22selector\x22: \x22#gnb_weather \x3e ul \x3e li \x3e a\x22\n    });\n\n    // \uae30\ub2a5 \uc601\uc5ed\n    click_codes.push({\n        \x22code\x22: \x22#util #widget_comment\x22 , \x22selector\x22: \x22#cSub .link_cmt\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #btn_summary\x22 , \x22selector\x22: \x22button.btn_summary\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #btn_share\x22 , \x22selector\x22: \x22button.btn_share\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #facebook\x22 , \x22selector\x22: \x22a.link_fb\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #kakaostory\x22 , \x22selector\x22: \x22a.link_ks\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #twitter\x22 , \x22selector\x22: \x22a.link_tw\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #mail\x22 , \x22selector\x22: \x22a.link_mail\x22\n    });\n    click_codes.push( ...
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_mArticle\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_mAside\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_translation_status\x22));"));
#
#
#
#
#
#
#
# (0,eval("(function(){ \n//\ubbf8\ub2c8\ub2e4\uc74c\n$(function(){\n  window.minidaum_options \x3d { \n    enableLogoutRetun: true,\n    disableTracker: true\n  }\n\n  $.ajax({url:\x22https://go.daum.net/minidaum_pc.daum\x22,cache:\x22true\x22,dataType:\x22script\x22});\n});\n\n// \uad11\uace0\n$(function(){\n  var channel \x3d \x27harmony\x27;\n  var cp \x3d window.cpId + \x27_pc_media_news\x27;\n  $(\x27.daum_ddn_area\x27).attr(\x27data-ad-param-channel\x27, channel).attr(\x27data-ad-param-cp\x27, cp);\n  $.ajax({\n    url: \x22//t1.daumcdn.net/adfit/static/ad.min.js\x22,\n    cache: true,\n    dataType: \x22script\x22\n  });\n});\n\n// floating GNB \x26 Wing\n$(function () {\n  var $window \x3d $(window),\n      $cMain \x3d $(\x22#cMain\x22),\n      $kakaoWrap \x3d $(\x22#kakaoWrap\x22),\n      $kakaoGnb \x3d $(\x22#kakaoGnb\x22),\n      headHeight \x3d $(\x22#wrapMinidaum\x22).outerHeight() + $(\x22.head_media\x22).outerHeight(),\n      $mArticle \x3d $(\x22#mArticle\x22),\n      $mAside \x3d $(\x22#mAside\x22),\n      adFirst \x3d $(\x22.aside_ad:first\x22),\n      adLast \x3d $(\x22.aside_ad:last\x22),\n      cmNews \x3d $(\x22.cmt_news\x22),\n      $barProgress \x3d $(\x22#barProgress\x22),\n      // \ub0a0\uac1c \ud53d\uc2a4\ub4dc\uc778 \uacbd\uc6b0 left \uc704\uce58\ub97c \uc9c0\uc815\ud558\uae30 \uc704\ud574 \ud558\ub2e8 \uc2e4\uc2dc\uac04 \uac80\uc0c9\uc5b4\uc758 left \uac12\uc744 \uc774\uc6a9. \ub9cc\uc57d \uc5c6\uc73c\uba74 \uacc4\uc0b0\uc744 \ud55c\ub2e4.\n      realtimeAsideEl \x3d document.getElementById(\x27realtime_aside\x27);\n\n\n  var floatGnb \x3d function () {\n    if ($window.scrollTop() \x3e headHeight) {\n      var scrollPercent \x3d 100 * $window.scrollTop() / ($(document).height() - $window.height());\n      $kakaoWrap.addClass(\x22header_fixed\x22);\n      $barProgress.width(parseInt(scrollPercent, 10) + \x22%\x22);\n    } else {\n      $kakaoWrap.removeClass(\x22header_fixed\x22);\n    }\n  };\n\n  var floatWing \x3d function () {\n    var cMainWidth \x3d $cMain.width(),\n        mArticleWidth \x3d $mArticle.width(),\n        mAsideWidth \x3d $mAside.width(),\n        aSideGap \x3d cMainWidth - mArticleWidth - mAsideWidth,\n        leftOfRealtimeAside \x3d realtimeAsideEl ? (realtimeAsideEl.getBoundingClientRect().left \x3c 880 ? realtimeAsideEl.getBoundingClientRect().left + $(window).scrollLeft() : realtimeAsideEl.getBoundingClientRect().left ) :  mArticleWidth + aSideGap + parseInt($cMain.css(\x22marginLeft\x22), 10) - $window.scrollLeft(),\n        topPosition \x3d $window.scrollTop() - 8 - ($cMain.position().top + adFirst.height());\n\n    if($(\x22#mArticle\x22).outerHeight() \x3c $(\x22#mAside\x22).outerHeight())\n      return;\n\n    $(\x22.cmt_view\x22).css(\x22min-height\x22, \x22250px\x22);\n    if (topPosition \x3e 0) {\n      var articleHeight \x3d $mArticle.outerHeight() - cmNews.outerHeight();\n      var wingHeight \x3d $mAside.outerHeight() - adLast.outerHeight();\n      if (articleHeight \x3e (wingHeight + topPosition + 8)) {\n        $mAside.css({\n          \x22position\x22 : \x22fixed\x22,\n          \x22top\x22 : $kakaoGnb.height() - adFirst.outerHeight() - 74,\n          \x22left\x22 : parseInt(leftOfRealtimeAside, 10)\n        });\n      } else {\n        $mAside.css({\n          \x22position\x22 : \x22relative\x22,\n          \x22top\x22 : articleHeight - wingHeight,\n          \x22left\x22 : \x22inherit\x22\n        });\n      }\n    } else {\n      $mAside.css({\n        \x22position\x22 : \x22static\x22,\n        \x22top\x22 : \x22inherit\x22,\n        \x22left\x22 : \x22inherit\x22\n      });\n    }\n  };\n\n  $(window).on(\x22scroll\x22, function () {\n    floatGnb();\n    floatWing();\n  });\n\n  $(window).on(\x22resize\x22, function() {\n    floatWing();\n  });\n\n  floatGnb();\n  floatWing();\n\n});\n\n})();"));
#
# </script>
# </body>
# </html>

# %%
# 3) requests를 통해서 웹에 있는 소스 가져오기
import requests

# web_url에 원하는 웹의 URL을 넣어주시면 됩니다.
web_url = "https://news.v.daum.net/v/20200321131028118"
r = requests.get(web_url)
r.status_code
r.headers['content-type']
r.encoding
r.text
# Out:
# '<!doctype html>\n<html lang="ko">\n <head> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=Edge"> \n  <meta name="referrer" content="always"> \n  <title>당 간판이 어째.. 국민 마음과 비례 않는 비례대표 | Daum 뉴스</title> \n  <link rel="shortcut icon" href="//m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico"> \n  <style>\n@charset "utf-8";@font-face{font-family:\'Nanum Myeongjo\';font-style:normal;font-weight:400;src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot);src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot?#iefix) format(\'embedded-opentype\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff2) format(\'woff2\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff) format(\'woff\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.ttf) format(\'truetype\')}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,textarea,button{margin:0;padding:0}fieldset,img{border:0 none}dl,ul,ol,menu,li{list-style:none}blockquote,q{quotes:none}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none}input,select,textarea,button{vertical-align:middle}input::-ms-clear{display:none}button{border:0 none;background-color:transparent;cursor:pointer}button::-moz-focus-inner{padding:0;border:0}body{min-width:980px;background:#fff}body,th,td,input,select,textarea,button{font-size:14px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,\'Malgun Gothic\',\'맑은 고딕\',dotum,\'돋움\',sans-serif;color:#333;letter-spacing:-0.05em}a{color:#333;text-decoration:none}a:active,a:hover{text-decoration:underline}a:hover{color:#1e88e5}a:active{background-color:transparent}address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}.os_mac strong{font-weight:normal;font-family:AppleSDGothicNeo-Regular,sans-serif}html{overflow-y:scroll}#kakaoIndex{overflow:hidden;position:absolute;left:-9999px;width:0;height:1px;margin:0;padding:0}.ir_pm{display:block;overflow:hidden;font-size:0;line-height:0;text-indent:-9999px}.ir_wa{display:block;overflow:hidden;position:relative;z-index:-1;width:100%;height:100%}.screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}.show{display:block}.hide{display:none}.txt_newsview{display:block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/txt_newsview_190618.png) 0 0 no-repeat;text-indent:-9999px;background-size:140px 750px}.ico_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview_190327.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:350px 350px}.ico_newsview2{background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview2_180510.png) 0 0 no-repeat;background-size:50px 440px}.num_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/num_newsview.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:18px 600px}.link_cont,.link_thumb,.tit_g,.tit_thumb,.desc_thumb,.info_thumb{display:block}.link_thumb{position:relative}.link_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:\'\'}.link_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;transition:background .2s,opacity .2s;content:\'\'}.link_thumb:hover:after{background:#508dee;opacity:.45}.link_cont .wrap_thumb{display:block;position:relative}.link_cont .wrap_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:\'\'}.link_cont .wrap_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;tran ...

# %%
# 4) find() 및 find_all()함수
# 함수 인자로는 찾고자 하는 태그의 이름, 속성 기타 등등이 들어간다.
# find_all(name, attrs, recursive, string, limit, **kwargs)
# find(name, attrs, recursive, string, **kwargs)

# 4-1) find_all() : 해당 조건에 맞는 모든 태그들을 가져온다.
# 모든 div를 찾는다.
with open("./example.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    all_divs = soup.find_all("div")
    print(all_divs)
# Out:
# [<div>
# <p>a</p>
# <p>b</p>
# <p>c</p>
# </div>, <div class="ex_class">
# <p>d</p>
# <p>e</p>
# <p>f</p>
# </div>, <div id="ex_id">
# <p>g</p>
# <p>h</p>
# <p>i</p>
# </div>]

# %%
# 4-2) find() : 해당 조건에 맞는 하나의 태그를 가져온다. 
# 중복이면 가장 첫 번째 태그를 가져온다.  
html = "./example.html"
with open(html) as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    first_div = soup.find("div")
    print(first_div)
# Out:
# <div>
# <p>a</p>
# <p>b</p>
# <p>c</p>
# </div>

# %%
# 4-3) 태그를 이용해서 가져오기
# 예제 : 모든 <p> 태그들을 가져오기    
html = "./example.html"
with open(html) as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    all_ps = soup.find_all("p")
    print(all_ps)
# Out:
# [<p>a</p>, <p>b</p>, <p>c</p>, <p>d</p>, <p>e</p>, <p>f</p>, <p>g</p>, <p>h</p>, <p>i</p>, <p>This is a paragraph.</p>, <p>This is another paragraph.</p>]

# %%
# 4-4) 예제 : 첫번째 <div>태그를 가져오기
html = "./example.html"
with open(html) as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    first_div = soup.find("div")
    print(first_div)
# Out:
# <div>
# <p>a</p>
# <p>b</p>
# <p>c</p>
# </div>

# %%
# 태그와 속성을 이용해서 가져오기

# 태그와 속성을 이용할 때 함수의 인자로 원하는 태그를 첫번째 인자로 
# 그 다음에 속성:값의 형태로 dictionary 형태로 만들어서 넣어주면 된다.

# find_all('태그명', {'속성명' : '값' ...})
# find('태그명', {'속성명' : '값' ...})

# HTML 구조를 이용해 원하는 부분 가져오기
# 예제 4-5) : <div> 태그에서 id속성의 값이 ex_id 인 것을  찾기
html = "./example.html"
with open(html) as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    ex_id_divs = soup.find('div', {'id' : 'ex_id'})
    print(ex_id_divs)
# Out:
# <div id="ex_id">
# <p>g</p>
# <p>h</p>
# <p>i</p>
# </div>

# %%
# 예제 4-6) : id속성의 값이 ex_id인 <div> 태그에서 <p>태그들만 가져오기
with open("example.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    # id=ex_id인 div 태그를 가져와서
    ex_id_divs = soup.find("div", {"id":"ex_id"})
    # 그 태그들 안에서 p 태그를 가져온다.
    all_ps_in_ex_id_divs = ex_id_divs.find_all("p")
    print(all_ps_in_ex_id_divs)
# Out:
# [<p>g</p>, <p>h</p>, <p>i</p>]
